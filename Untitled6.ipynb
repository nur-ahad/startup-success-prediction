# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
from imblearn import under_sampling, over_sampling
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
data = pd.read_csv("Desktop\Solar Business\solar features.csv")

# %%
data.head()
print('There are', str(len(data)), 'rows of data in this dataset')
print('There are', str(data.shape[1]), 'features in this dataset')
data.head(15)
# Out:
# There are 169 rows of data in this dataset
# There are 29 features in this dataset
#    prefecture_code  post_code       city plant_name founding_year  \
# 0               SH    4380112      Iwata  Shimonobe      1/1/2023
# 1               SH    4380112      Iwata  Shimonobe      1/2/2023
# 2               SH    4380112      Iwata  Shimonobe      1/3/2023
# 3               SH    4380112      Iwata  Shimonobe      1/4/2023
# 4               SH    4380112      Iwata  Shimonobe      1/5/2023
# 5               SH    4350022  Hamamatsu    Tsurumi      1/6/2023
# 6               SH    4350022  Hamamatsu    Tsurumi      1/7/2023
# 7               SH    4350022  Hamamatsu    Tsurumi      1/8/2023
# 8               SH    4350022  Hamamatsu    Tsurumi      1/9/2023
# 9               SH    4350022  Hamamatsu    Tsurumi     1/10/2023
# 10              SH    4358560  Hamamatsu   Furukawa     1/11/2023
# 11              SH    4358560  Hamamatsu   Furukawa     1/12/2023
# 12              SH    4358560  Hamamatsu   Furukawa      1/1/2024
# 13              SH    4358560  Hamamatsu   Furukawa      1/2/2024
# 14              SH    4358560  Hamamatsu   Furukawa      1/3/2024
#
#    initial_funding_year initial_funding_total_yen  intial_funding_age  \
# 0              1/2/2023                10,000,000                  20
# 1              1/3/2023                10,000,000                  19
# 2              1/4/2023                10,000,000                  23
# 3              1/5/2023                10,000,000                  20
# 4              1/6/2023                10,000,000                  22
# 5              1/7/2023                12,000,000                  21
# 6              1/8/2023                12,000,000                  20
# 7              1/9/2023                12,000,000                  23
# 8             1/10/2023                12,000,000                  20
# 9             1/11/2023                12,000,000                  21
# 10            1/12/2023                10,000,000                  20
# 11             1/1/2024                10,000,000                  20
# 12             1/2/2024                10,000,000                  21
# 13             1/3/2024                10,000,000                  19
# 14             1/4/2024                10,000,000                  20
#
#     milestones_achieved   first_funding_age  ...  business_model_type  \
# 0                      0                 82  ...                    1
# 1                      0                 65  ...                    1
# 2                      1                 70  ...                    1
# 3                      1                 75  ...                    1
# 4                      1                 65  ...                    1
# 5                      0                 70  ...                    1
# 6                      0                 75  ...                    1
# 7                      0                 80  ...                    1
# 8                      1                 85  ...                    1
# 9                      1                 60  ...                    0
# 10                     0                 65  ...                    0
# 11                     0                 70  ...                    0
# 12                     2                 75  ...                    0
# 13                     2                 80  ...                    0
# 14                     2                 85  ...                    0
#
#     number_collaboration competitor_count  research_team_size  time_to_market  \
# 0                      1                4                   1             180
# 1                      1                4                   1             185
# 2                      1                4                   1             190
# 3                      1                4                   1             195
# 4                      0                5                   1             200
# 5                      0                5                   1             205
# 6                      0                5                   1             210
# 7                      0                5                   1             215
# 8                      2                5                   1             220
# 9                      2                4                   1             225
# 10                     2                4                   1             230
# 11                     2                4                   1             235
# 12                     3                4                   2             240
# 13                     3                4                   2             245
# 14                     3                4                   2             250
#
#     industry_knowledge  social_value_creation  market_estimation  has_domain  \
# 0                    0                      0                100           0
# 1                    0                      1                100           0
# 2                    0                      0                100           0
# 3                    0                      0                100           0
# 4                    0                      0                200           0
# 5                    1                      1                200           1
# 6                    1                      1                200           1
# 7                    1                      1                200           1
# 8                    1                      1                250           1
# 9                    1                      0                250           1
# 10                   0                      0                250           1
# 11                   0                      0                250           1
# 12                   0                      0                300           1
# 13                   0                      0                300           1
# 14                   0                      1                300           1
#
#     target_marketsize
# 0                  10
# 1                  10
# 2                  10
# 3                  10
# 4                  25
# 5                  25
# 6                  25
# 7                  25
# 8                  30
# 9                  30
# 10                 30
# 11                 30
# 12                 50
# 13                 50
# 14                 50
#
# [15 rows x 29 columns]

# %%
#Check Dataset 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   prefecture_code            169 non-null    object
#  1   post_code                  169 non-null    int64
#  2   city                       169 non-null    object
#  3   plant_name                 169 non-null    object
#  4   founding_year              169 non-null    object
#  5   initial_funding_year       169 non-null    object
#  6   initial_funding_total_yen  169 non-null    object
#  7   intial_funding_age         169 non-null    int64
#  8   milestones_achieved        169 non-null    int64
#  9   first_funding_age          169 non-null    int64
#  10  second_funding_age         136 non-null    float64
#  11  has_collaboration          169 non-null    int64
#  12  category_code              169 non-null    object
#  13  is_automotive              169 non-null    int64
#  14  is_energy                  169 non-null    int64
#  15  is_healthcare              169 non-null    int64
#  16  has_vc                     169 non-null    int64
#  17  has_new_employees          169 non-null    int64
#  18  employee_count             169 non-null    int64
#  19  business_model_type        169 non-null    int64
#  20  number_collaboration       169 non-null    int64
#  21  competitor_count           169 non-null    int64
#  22  research_team_size         169 non-null    int64
#  23  time_to_market             169 non-null    int64
#  24  industry_knowledge         169 non-null    int64
#  25  social_value_creation      169 non-null    int64
#  26  market_estimation          169 non-null    int64
#  27  has_domain                 169 non-null    int64
#  28  target_marketsize          169 non-null    int64
# dtypes: float64(1), int64(21), object(7)
# memory usage: 38.4+ KB

# %%
data.describe()
# Out:
#           post_code  intial_funding_age  milestones_achieved   \
# count  1.690000e+02          169.000000            169.000000
# mean   4.363305e+06           20.698225              2.023669
# std    1.281936e+04            1.357540              1.184989
# min    4.350022e+06           18.000000              0.000000
# 25%    4.350022e+06           20.000000              1.000000
# 50%    4.358560e+06           21.000000              2.000000
# 75%    4.380112e+06           21.000000              3.000000
# max    4.380112e+06           25.000000              5.000000
#
#        first_funding_age  second_funding_age  has_collaboration  \
# count         169.000000          136.000000         169.000000
# mean           86.295858          127.580882           0.467456
# std            19.932506           23.141611           0.500422
# min            50.000000           90.000000           0.000000
# 25%            70.000000          110.000000           0.000000
# 50%            85.000000          123.500000           0.000000
# 75%           100.000000          145.000000           1.000000
# max           150.000000          185.000000           1.000000
#
#        is_automotive   is_energy  is_healthcare      has_vc  ...  \
# count     169.000000  169.000000     169.000000  169.000000  ...
# mean        0.307692    0.331361       0.360947    0.390533  ...
# std         0.462910    0.472101       0.481702    0.489320  ...
# min         0.000000    0.000000       0.000000    0.000000  ...
# 25%         0.000000    0.000000       0.000000    0.000000  ...
# 50%         0.000000    0.000000       0.000000    0.000000  ...
# 75%         1.000000    1.000000       1.000000    1.000000  ...
# max         1.000000    1.000000       1.000000    1.000000  ...
#
#        business_model_type  number_collaboration  competitor_count  \
# count           169.000000            169.000000        169.000000
# mean              1.023669              2.124260          3.881657
# std               0.808825              1.181178          1.214087
# min               0.000000              0.000000          2.000000
# 25%               0.000000              1.000000          3.000000
# 50%               1.000000              2.000000          4.000000
# 75%               2.000000              3.000000          5.000000
# max               2.000000              4.000000          6.000000
#
#        research_team_size  time_to_market  industry_knowledge  \
# count          169.000000      169.000000          169.000000
# mean             1.733728      301.005917            0.485207
# std              0.869516       74.507470            0.501266
# min              1.000000      180.000000            0.000000
# 25%              1.000000      235.000000            0.000000
# 50%              2.000000      305.000000            0.000000
# 75%              2.000000      355.000000            1.000000
# max              4.000000      470.000000            1.000000
#
#        social_value_creation  market_estimation  has_domain  target_marketsize
# count             169.000000         169.000000  169.000000         169.000000
# mean                0.508876         301.893491    0.562130          68.923077
# std                 0.501407         178.950214    0.497599          55.261069
# min                 0.000000          45.000000    0.000000           4.000000
# 25%                 0.000000         180.000000    0.000000          30.000000
# 50%                 1.000000         280.000000    1.000000          54.000000
# 75%                 1.000000         380.000000    1.000000          96.000000
# max                 1.000000         700.000000    1.000000         210.000000
#
# [8 rows x 22 columns]

# %%
data['has_collaboration'].value_counts()
# Out:
# 0    90
# 1    79
# Name: has_collaboration, dtype: int64

# %%
data['business_model_type'].value_counts()
# Out:
# 1    59
# 2    57
# 0    53
# Name: business_model_type, dtype: int64

# %%
data['is_automotive'].value_counts()
# Out:
# 0    117
# 1     52
# Name: is_automotive, dtype: int64

# %%
data['is_energy'].value_counts()
# Out:
# 0    113
# 1     56
# Name: is_energy, dtype: int64

# %%
data['is_healthcare'].value_counts()
# Out:
# 0    108
# 1     61
# Name: is_healthcare, dtype: int64

# %%
data['industry_knowledge'].value_counts()
# Out:
# 0    87
# 1    82
# Name: industry_knowledge, dtype: int64
